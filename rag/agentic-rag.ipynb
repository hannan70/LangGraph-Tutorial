# %%
import os
from dotenv import load_dotenv
load_dotenv()

# import necessery tools
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from IPython.display import Image, Markdown
from pydantic import BaseModel, Field
from langchain_core.messages import HumanMessage, SystemMessage
import operator

# %%
os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("what is agentic ai")
# Out:
# AIMessage(content="Agentic AI refers to artificial intelligence (AI) systems that possess agency, which means they have the ability to act autonomously, make decisions, and take actions based on their own goals, motivations, and intentions. These AI systems are designed to be proactive, adaptable, and interactive, often learning from their environment and adjusting their behavior accordingly.\n\nAgentic AI systems typically exhibit the following characteristics:\n\n1. **Autonomy**: They can operate independently, making decisions and taking actions without human intervention.\n2. **Goal-oriented**: They have specific objectives or goals that guide their behavior and decision-making.\n3. **Reactivity**: They can respond to changes in their environment, adapting to new situations and stimuli.\n4. **Proactivity**: They can anticipate and take action to achieve their goals, rather than simply reacting to events.\n5. **Learning**: They can learn from experience, updating their knowledge and behavior based on feedback and outcomes.\n6. **Social interaction**: They can interact with humans and other agents, communicating and cooperating to achieve shared goals.\n\nAgentic AI has numerous applications across various domains, including:\n\n1. **Robotics**: Autonomous robots that can navigate, manipulate objects, and interact with humans.\n2. **Virtual assistants**: AI-powered assistants that can manage schedules, provide recommendations, and perform tasks on behalf of users.\n3. **Smart homes**: AI systems that can control and optimize home automation, energy management, and security.\n4. **Healthcare**: AI-powered systems that can monitor patient health, provide personalized recommendations, and assist with diagnosis and treatment.\n5. **Finance**: AI-powered trading systems that can analyze market data, make predictions, and execute trades autonomously.\n\nThe development of agentic AI raises important questions and challenges, such as:\n\n1. **Ethics**: How can we ensure that agentic AI systems align with human values and principles?\n2. **Safety**: How can we guarantee the safe operation of agentic AI systems, particularly in critical domains like healthcare and finance?\n3. **Transparency**: How can we provide insights into the decision-making processes of agentic AI systems?\n4. **Accountability**: How can we hold agentic AI systems accountable for their actions and outcomes?\n\nAs agentic AI continues to evolve, it's essential to address these challenges and develop frameworks that ensure the responsible development and deployment of these systems.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 475, 'prompt_tokens': 40, 'total_tokens': 515, 'completion_time': 1.8687172890000001, 'completion_tokens_details': None, 'prompt_time': 0.005661074, 'prompt_tokens_details': None, 'queue_time': 0.048999106, 'total_time': 1.874378363}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d161c-7a47-7cb2-8e3a-873b1d965007-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 475, 'total_tokens': 515})
